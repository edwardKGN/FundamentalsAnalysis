# %%
import pandas as pd # Pre-requisite to run Pandas
from pandas import Series, DataFrame
import numpy as np # Pre-requisite to run numpy

# %%
# Name of File
file_name = "Bursa_financialServices_benchmark"
sheet_name = "Sheet1"

# %%
# Update to include Formatting
xlsx_file_name = file_name + ".xlsx"

# %%
# Extract Key Data from Raw Benchmark Data
benchmark_raw = pd.read_excel(xlsx_file_name, sheet_name)
benchmark_raw
# Out:
#     Financial Ratios          2020          2019          2018          2017  \
# 0            General           NaN           NaN           NaN           NaN
# 1          Valuation           NaN           NaN           NaN           NaN
# 2      Price to Book  8.126068e+00  7.228567e+00  6.839563e+00  6.653040e+00
# 3                NaN  6.700000e+06  4.900000e+06  5.500000e+06  5.400000e+06
# 4                NaN  6.700000e+09  4.900000e+09  5.500000e+09  5.400000e+09
# ..               ...           ...           ...           ...           ...
# 277              NaN           NaN           NaN           NaN           NaN
# 278              NaN           NaN           NaN           NaN           NaN
# 279              NaN           NaN           NaN           NaN           NaN
# 280    Miscellaneous           NaN           NaN           NaN           NaN
# 281              NaN           NaN           NaN           NaN           NaN
#
#              2016
# 0             NaN
# ...

# %%
benchmark_raw = benchmark_raw.dropna()
benchmark_raw
# Out:
#                Financial Ratios        2020        2019        2018  \
# 2                 Price to Book    8.126068    7.228567    6.839563
# 13            Price to Earnings   17.736739   25.849608   23.849376
# 21             Return on Equity    0.419348    0.249168    0.259862
# 25   Return on Capital Employed    0.546180    0.324321    0.336581
# 31      EBITDA to Revenue Ratio    0.678694    0.577077    0.631922
# 41    EBITDA to Cash Conversion    0.789371    0.673565    0.648027
# 50     Revenue to Expense Ratio    1.947835    1.643426    1.759434
# 55                Current Ratio    1.202994    1.211251    1.201852
# 59                   Cash Ratio    0.124348    0.121174    0.110692
# 63    Operating Cash Flow Ratio    0.181070    0.121917    0.141224
# 67        Cash Conversion Ratio    1.104544    0.984543    0.929211
# 72                   Debt Ratio    0.000000    0.000000    0.000000
# 76         Debt to Equity Ratio    0.000000    0.000000    0.000000
# ...

# %%
benchmark_raw = benchmark_raw.reset_index(drop = True)
benchmark_raw
# Out:
#               Financial Ratios        2020        2019        2018  \
# 0                Price to Book    8.126068    7.228567    6.839563
# 1            Price to Earnings   17.736739   25.849608   23.849376
# 2             Return on Equity    0.419348    0.249168    0.259862
# 3   Return on Capital Employed    0.546180    0.324321    0.336581
# 4      EBITDA to Revenue Ratio    0.678694    0.577077    0.631922
# 5    EBITDA to Cash Conversion    0.789371    0.673565    0.648027
# 6     Revenue to Expense Ratio    1.947835    1.643426    1.759434
# 7                Current Ratio    1.202994    1.211251    1.201852
# 8                   Cash Ratio    0.124348    0.121174    0.110692
# 9    Operating Cash Flow Ratio    0.181070    0.121917    0.141224
# 10       Cash Conversion Ratio    1.104544    0.984543    0.929211
# 11                  Debt Ratio    0.000000    0.000000    0.000000
# 12        Debt to Equity Ratio    0.000000    0.000000    0.000000
# ...

# %%
output_file_name = file_name + "_cleaned" + ".xlsx"
benchmark_raw.to_excel(output_file_name)
